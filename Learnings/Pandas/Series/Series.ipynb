# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Dataset_Sample.csv')
df.head()
# Out:
#    No        Name  Type1   Type2  Height  Weight  Legendary
# 0   1   Bulbasaur  Grass  Poison     0.7     6.9          0
# 1   2     Ivysaur  Grass  Poison     1.0    13.0          0
# 2   3    Venusaur  Grass  Poison     2.0   100.0          0
# 3   4  Charmander   Fire     NaN     0.6     8.5          0
# 4   5  Charmeleon   Fire     NaN     1.1    19.0          0

# %%
s = pd.Series([10,20,30,40,50])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = "Numbers"
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64

# %% [markdown]
# ### Indexing

# %%
s[0]
# Out:
# np.int64(10)

# %%
s[0:2]
# Out:
# 0    10
# 1    20
# Name: Numbers, dtype: int64

# %%
s[2:4]
# Out:
# 2    30
# 3    40
# Name: Numbers, dtype: int64

# %% [markdown]
# #### iloc -> location based indexing

# %%
s.iloc[2]
# Out:
# np.int64(30)

# %%
# for selecting multiple
s.iloc[[1,2,3]]
# Out:
# 1    20
# 2    30
# 3    40
# Name: Numbers, dtype: int64

# %%
index = ['Apple','Banana','graphs','orange','strawberry']
s.index = index
s
# Out:
# Apple         10
# Banana        20
# graphs        30
# orange        40
# strawberry    50
# Name: Numbers, dtype: int64

# %%
s['graphs']
# Out:
# np.int64(30)

# %%
# s.iloc['graphs'] we cannot access the element using iloc after giving manual index 

#in label based indexing your start as well as stop value both are includeed in the output
s['banana':'orange']
# Out:
# graphs    30
# orange    40
# Name: Numbers, dtype: int64
