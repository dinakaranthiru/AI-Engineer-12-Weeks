# %% [markdown]
# ## Countplot
# 1. import all the required libraries
# 2. Create a basic COUNTPLOT to get number for each of thr product linr and change the figure size
# 3. Make it horizontal barplot
# 4. Add hue to get the count on two categoties
# 5. using differnrt color palette

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('annual_gold_rates.csv')
df.head()
# Out:
#       Date    Market Purity     USD     EUR     GBP       INR      AED  \
# 0  1979-04   Kolkata    18K  231.76  140.77  108.84   1887.88   885.36
# 1  2002-09   Kolkata    22K  280.67  297.25  186.83  13633.03  1030.90
# 2  2000-08     Delhi    24K  281.11  304.92  185.67       NaN  1032.50
# 3  1990-11   Chennai    24K  383.12  282.62  215.71   6689.93  1406.18
# 4  2002-06  New York    24K  303.26  321.17  201.86  14729.96  1113.85
#
#        CNY
# 0   704.86
# 1  2323.10
# 2  2327.15
# 3  1825.02
# 4  2510.02

# %%
plt.figure(figsize=(10,7))
# sns.countplot(y='Market',data=df) #horizontal
sns.countplot(x='Market',hue='Purity',data=df) #Vertical
# Out:
# <Axes: xlabel='Market', ylabel='count'>
