# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.11.0

# %%
import matplotlib.pyplot as plt

x = [2021,2022,2023,2024,2025,2026]
y = [0,10000,60000,80000,100000,200000]

plt.plot(x,y,marker = ".",markersize = 10,markerfacecolor="red",markeredgewidth=1,linestyle="dashed")
plt.show()

# %%
plt.plot(y)

# %%
a=[20,44,11,90,50]
b=[""]
