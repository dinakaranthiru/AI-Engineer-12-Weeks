# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([2023,2024,2025,2026,])
y1 = np.array([15,25,30,20])
y2=np.array([17,23,38,5])
y3 = np.array([16,28,45,10])

# plt.plot(x,y1,
#                 marker = '.',
#                 markersize=20,
#                 markerfacecolor='cyan',
#                 markeredgecolor='cyan',
#                 inestyle='solid',
#                 linewidth=4)
# plt.plot(x,y2,
#                 marker = '.',
#                 markersize=20,
#                 markerfacecolor='cyan',
#                 markeredgecolor='cyan',
#                 linestyle="solid",
#                 linewidth=4)
#insted of using multiple time  we can difine it in a dictionary and use whereever we need.
line_style = dict(marker = '.',
                  markersize=20,
                  markerfacecolor='cyan',
                  markeredgecolor='cyan',
                  linestyle='solid',
                  linewidth=4)
plt.plot(x,y1,color='red', **line_style)
plt.plot(x,y2,color='blue',**line_style)
plt.plot(x,y3,color='green',**line_style)
plt.show()

# %% [markdown]
# # labels

# %%
plt.title("Class size",
          fontsize=25,
          fontweight='bold',
          color='#2d4cfc')
plt.xlabel("Year",
           fontsize=20,
           fontweight='bold',
           color='#2dbefc')
plt.ylabel("Students No",
           fontsize=20,
           fontweight='bold',
           color='#2dbefc')

plt.tick_params(axis='x', labelsize=12)



plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

plt.xticks(x)
# Out:
# ([<matplotlib.axis.XTick at 0x272265afc50>,
# ...
#  [Text(2023, 0, '2023'),
#   Text(2024, 0, '2024'),
#   Text(2025, 0, '2025'),
#   Text(2026, 0, '2026')])

# %% [markdown]
# # Grid() = Help make the plots easier to read by adding reference lines

# %%
x = [1,2,3,4,5]
y=[5,10,15,20,25]

plt.grid(axis='y',
         linewidth=2,
         color='lightgray',
         linestyle='dashed'
         )
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Bar charts = compare categories of data by representing each category with a bar

# %%
cat = ["Grains",'Fruits','vegetables','Protiens','Dairy','Sweets']
values = np.array([4,3,2,5,3,1])

# plt.bar(cat,values,color = 'red')
#For horizontal barchart we have to use the barh
plt.barh(cat,values,color = 'red')

plt.title("Daily Consumption")
plt.xlabel('Food')
plt.show()

# %% [markdown]
# # Pie chart = circular chart divided into slices to show percentage of the total.

# %%
categories = ["Freshman","Sophomores","juniors","Seniors"]
values = np.array([300,250,275,225])
colors = ['red','blue','green','yellow']

plt.pie(values,labels = categories,autopct = "%1.1f%%",colors = colors,explode=[0,0.05,0,0])
plt.show()

# %% [markdown]
# # Scatter plot =  shows the relationship between two variables , helps to identify a correlation (+,-,None)
# Example: Study hours vs Test Scores

# %%
x1 = [0,1,1,2,3,4,5,6,7,7,8]
y1 = [55,60,65,62,68,70,75,78,82,85,87]

x2= [0,1,2,2,3,4,5,6,7,8,8]
y2 = [50,58,65,70,72,78,84,88,92,95,97]

plt.scatter(x1,y1,color = 'red',alpha=0.5,s=100,label = "Class A")
plt.scatter(x2,y2,color = 'blue',alpha=0.5,s=100,label = "Class B")
plt.xlabel("Hours studied")
plt.ylabel("Grade")
plt.legend()
plt.title("Test Scores")
# Out:
# Text(0.5, 1.0, 'Test Scores')

# %% [markdown]
# # Histograms =  a visual representaion of the distribution of quantitative data.
# They group vaules into bins(intervals)
# and count how many fall in each range

# %%
scores = np.random.normal(loc = 80,scale=10,size = 100)
plt.hist(scores,bins=5,color='lightgreen',edgecolor = 'black')
# Out:
# (array([ 8., 19., 41., 29.,  3.]),
#  array([ 52.60373178,  62.76225024,  72.9207687 ,  83.07928716,
#          93.23780562, 103.39632408]),
#  <BarContainer object of 5 artists>)
