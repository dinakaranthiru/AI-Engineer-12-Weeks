# %% [markdown]
# # Data Cleaning using pandas

# %%
import pandas as pd

# %%
df = pd.read_json('sample1.json')
df.head()
# Out:
#    id       name    class  marks
# 0   1  Student 1  Class A     81
# 1   1  Student 1  Class A     81
# 2   2  Student 2  Class B     72
# 3   2  Student 2  Class B     72
# 4   3  Student 3  Class C     65

# %% [markdown]
# # dropping a cloumn

# %%
df = df.drop(columns=["id"])
df.head()
# Out:
#         name    class  marks
# 0  Student 1  Class A     81
# 1  Student 1  Class A     81
# 2  Student 2  Class B     72
# 3  Student 2  Class B     72
# 4  Student 3  Class C     65

# %% [markdown]
# # To clean NaN in data

# %%
df = df.dropna(subset=["marks"])
df
# Out:
#           name    class  marks
# 0    Student 1  Class A     81
# 1    Student 1  Class A     81
# 2    Student 2  Class B     72
# 3    Student 2  Class B     72
# 4    Student 3  Class C     65
# 5    Student 3  Class C     65
# 6    Student 4  Class A     90
# 7    Student 5  Class B     58
# 8    Student 6  Class C     76
# 9    Student 7  Class A     84
# 10   Student 8  Class B     69
# 11   Student 9  Class C     73
# 12  Student 10  Class A     62
# 13  Student 11  Class B     88
# 14  Student 12  Class C     91
# 15  Student 13  Class A     55
# 16  Student 14  Class B     79
# 17  Student 15  Class C     67
# 18  Student 16  Class A     82
# 19  Student 17  Class B     74
# 20  Student 18  Class C     63
# 21  Student 19  Class A     95
# 22  Student 20  Class B     61
# 23  Student 21  Class C     77
# 24  Student 22  Class A     89
# 25  Student 23  Class B     70
# 26  Student 24  Class C     64
# 27  Student 25  Class A     83
# 28  Student 26  Class B     56
# ...

# %% [markdown]
# # if we have an NaN in an column instead of NaN we can define what value need to present in the NaN position

# %%
df = df.fillna({
    "marks":99
})
df
# Out:
#           name    class  marks
# 0    Student 1  Class A     81
# 1    Student 1  Class A     81
# 2    Student 2  Class B     72
# 3    Student 2  Class B     72
# 4    Student 3  Class C     65
# 5    Student 3  Class C     65
# 6    Student 4  Class A     90
# 7    Student 5  Class B     58
# 8    Student 6  Class C     76
# 9    Student 7  Class A     84
# 10   Student 8  Class B     69
# 11   Student 9  Class C     73
# 12  Student 10  Class A     62
# 13  Student 11  Class B     88
# 14  Student 12  Class C     91
# 15  Student 13  Class A     55
# 16  Student 14  Class B     79
# 17  Student 15  Class C     67
# 18  Student 16  Class A     82
# 19  Student 17  Class B     74
# 20  Student 18  Class C     63
# 21  Student 19  Class A     95
# 22  Student 20  Class B     61
# 23  Student 21  Class C     77
# 24  Student 22  Class A     89
# 25  Student 23  Class B     70
# 26  Student 24  Class C     64
# 27  Student 25  Class A     83
# 28  Student 26  Class B     56
# ...

# %% [markdown]
# # To replace a value

# %%
df['class'] = df['class'].replace({
    "Class A": "IT",
    "Class B": "CSE",
    "Class C": "EEE"
})
df
# Out:
#     id        name class  marks
# 0    1   Student 1    IT   99.0
# 1    2   Student 2   CSE   99.0
# 2    3   Student 3   EEE   65.0
# 3    4   Student 4    IT   90.0
# 4    5   Student 5   CSE   58.0
# 5    6   Student 6   EEE   76.0
# 6    7   Student 7    IT   84.0
# 7    8   Student 8   CSE   69.0
# 8    9   Student 9   EEE   73.0
# 9   10  Student 10    IT   62.0
# 10  11  Student 11   CSE   88.0
# 11  12  Student 12   EEE   91.0
# 12  13  Student 13    IT   55.0
# 13  14  Student 14   CSE   79.0
# 14  15  Student 15   EEE   67.0
# 15  16  Student 16    IT   82.0
# 16  17  Student 17   CSE   74.0
# 17  18  Student 18   EEE   63.0
# 18  19  Student 19    IT   95.0
# 19  20  Student 20   CSE   61.0
# 20  21  Student 21   EEE   77.0
# 21  22  Student 22    IT   89.0
# 22  23  Student 23   CSE   70.0
# 23  24  Student 24   EEE   64.0
# 24  25  Student 25    IT   83.0
# 25  26  Student 26   CSE   56.0
# 26  27  Student 27   EEE   92.0
# 27  28  Student 28    IT   68.0
# ...

# %% [markdown]
# # To remove duplicates

# %%
df = df.drop_duplicates()
df
# Out:
#           name    class  marks
# 0    Student 1  Class A     81
# 2    Student 2  Class B     72
# 4    Student 3  Class C     65
# 6    Student 4  Class A     90
# 7    Student 5  Class B     58
# 8    Student 6  Class C     76
# 9    Student 7  Class A     84
# 10   Student 8  Class B     69
# 11   Student 9  Class C     73
# 12  Student 10  Class A     62
# 13  Student 11  Class B     88
# 14  Student 12  Class C     91
# 15  Student 13  Class A     55
# 16  Student 14  Class B     79
# 17  Student 15  Class C     67
# 18  Student 16  Class A     82
# 19  Student 17  Class B     74
# 20  Student 18  Class C     63
# 21  Student 19  Class A     95
# 22  Student 20  Class B     61
# 23  Student 21  Class C     77
# 24  Student 22  Class A     89
# 25  Student 23  Class B     70
# 26  Student 24  Class C     64
# 27  Student 25  Class A     83
# 28  Student 26  Class B     56
# 29  Student 27  Class C     92
# 30  Student 28  Class A     68
# 31  Student 29  Class B     71
# ...
