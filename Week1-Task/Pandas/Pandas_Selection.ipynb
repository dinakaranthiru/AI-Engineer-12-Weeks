# %%
import pandas as pd
df = pd.read_csv('Dataset_Sample.csv',index_col='Name')
df.head()
# Out:
#             No  Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur    1  Grass  Poison     0.7     6.9          0
# Ivysaur      2  Grass  Poison     1.0    13.0          0
# Venusaur     3  Grass  Poison     2.0   100.0          0
# Charmander   4   Fire     NaN     0.6     8.5          0
# Charmeleon   5   Fire     NaN     1.1    19.0          0

# %% [markdown]
# # Select by colums

# %%
#Selection
# print(df['Name'].to_string())
# print(df['Height'].to_string())
# print(df['Weight'].to_string())
print(df[["Height","Weight"]].to_string())
# Out:
#             Height  Weight
# Name
# Bulbasaur      0.7     6.9
# Ivysaur        1.0    13.0
# Venusaur       2.0   100.0
# Charmander     0.6     8.5
# Charmeleon     1.1    19.0
# Charizard      1.7    90.5
# Squirtle       0.5     9.0
# Wartortle      1.0    22.5
# Blastoise      1.6    85.5
# Caterpie       0.3     2.9
# Metapod        0.7     9.9
# Butterfree     1.1    32.0
# Weedle         0.3     3.2
# Kakuna         0.6    10.0
# Beedrill       1.0    29.5
# Pidgey         0.3     1.8
# Pidgeotto      1.1    30.0
# Pidgeot        1.5    39.5
# Rattata        0.3     3.5
# Raticate       0.7    18.5
# Spearow        0.3     2.0
# Fearow         1.2    38.0
# Ekans          2.0     6.9
# Arbok          3.5    65.0
# Pikachu        0.4     6.0
# Raichu         0.8    30.0
# Sandshrew      0.6    12.0
# Sandslash      1.0    29.5
# Nidoran♀       0.4     7.0
# Nidorina       0.8    20.0
# Nidoqueen      1.3    60.0
# Nidoran♂       0.5     9.0
# Nidorino       0.9    19.5
# ...

# %% [markdown]
# # Select by rows

# %%
# print(df.loc["Pikachu",["Height","Weight"]]) #only displaying selcted columns

print(df.iloc[0:11:3,0:4])
# Out:
#             No  Type1   Type2  Height
# Name
# Bulbasaur    1  Grass  Poison     0.7
# Charmander   4   Fire     NaN     0.6
# Squirtle     7  Water     NaN     0.5
# Caterpie    10    Bug     NaN     0.3

# %%
pokemon = input("Enter pokemon name: ")

try:
    print(df.loc[pokemon])
except KeyError:
    print(f"{pokemon} not found")
# Out:
# nbjhkoknjk not found
